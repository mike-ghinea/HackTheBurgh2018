# %%
import serial

# %%
ser = serial.Serial()

# %%
ser.port = 'COM5'

# %%
ser.read()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-4-32f6e7f1578c> in <module>()
# ----> 1 ser.read()
#
# c:\users\manpu\appdata\local\programs\python\python36-32\lib\site-packages\serial\serialwin32.py in read(self, size)
#     265         """
#     266         if not self.is_open:
# --> 267             raise portNotOpenError
#     268         if size > 0:
#     269             win32.ResetEvent(self._overlapped_read.hEvent)
#
# SerialException: Attempting to use a port that is not open

# %%
ser.open()

# %%
ser
# Out:
# Serial<id=0x7480d70, open=True>(port='COM5', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-935fc7485601> in <module>()
#       3 t_end = time.time() + 120
#       4 while time.time() < t_end:
# ----> 5     temperatures.append(float(str(ser.readline()[:-1])[2:-1]))
#
# c:\users\manpu\appdata\local\programs\python\python36-32\lib\site-packages\serial\serialwin32.py in read(self, size)
#     288                     ctypes.byref(self._overlapped_read),
#     289                     ctypes.byref(rc),
# --> 290                     True)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %%
temperatures = []
import time
t_end = time.time() + 120
while time.time() < t_end:
    temperatures.append(float(str(ser.readline()[:-1])[2:-1]))
ser.close()

# %%
temperatures
# Out:
# [5.539406,
#  25.523384,
#  25.552757,
#  25.539406,
#  25.523384,
#  25.523384,
#  25.539406,
#  25.539406,
#  25.539406,
#  25.552757,
#  25.539406,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.539406,
#  25.539406,
#  25.582132,
#  25.552757,
#  25.566111,
#  25.539406,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.582132,
#  25.608835,
#  25.582132,
#  25.608835,
#  25.595484,
#  25.595484,
#  25.595484,
#  25.582132,
#  25.595484,
#  25.595484,
#  25.582132,
#  25.608835,
#  25.624857,
#  25.608835,
#  25.624857,
#  25.595484,
#  25.595484,
#  25.608835,
#  25.595484,
#  25.608835,
#  25.608835,
#  25.624857,
#  25.608835,
#  25.608835,
#  25.624857,
#  25.638208,
#  25.608835,
#  25.624857,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.624857,
#  25.624857,
#  25.624857,
#  25.608835,
#  25.638208,
# ...

# %%
temperatures = temperatures[1:]

# %%
temperatures
# Out:
# [25.523384,
#  25.552757,
#  25.539406,
#  25.523384,
#  25.523384,
#  25.539406,
#  25.539406,
#  25.539406,
#  25.552757,
#  25.539406,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.539406,
#  25.539406,
#  25.582132,
#  25.552757,
#  25.566111,
#  25.539406,
#  25.552757,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.552757,
#  25.566111,
#  25.566111,
#  25.582132,
#  25.608835,
#  25.582132,
#  25.608835,
#  25.595484,
#  25.595484,
#  25.595484,
#  25.582132,
#  25.595484,
#  25.595484,
#  25.582132,
#  25.608835,
#  25.624857,
#  25.608835,
#  25.624857,
#  25.595484,
#  25.595484,
#  25.608835,
#  25.595484,
#  25.608835,
#  25.608835,
#  25.624857,
#  25.608835,
#  25.608835,
#  25.624857,
#  25.638208,
#  25.608835,
#  25.624857,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.638208,
#  25.624857,
#  25.624857,
#  25.624857,
#  25.608835,
#  25.638208,
#  25.638208,
# ...

# %%
import numpy as np
temp = np.array(temperatures)

# %%
temp
# Out:
# array([25.523384, 25.552757, 25.539406, 25.523384, 25.523384, 25.539406,
#        25.539406, 25.539406, 25.552757, 25.539406, 25.566111, 25.566111,
#        25.552757, 25.552757, 25.566111, 25.566111, 25.552757, 25.552757,
#        25.566111, 25.539406, 25.539406, 25.582132, 25.552757, 25.566111,
#        25.539406, 25.552757, 25.552757, 25.566111, 25.566111, 25.552757,
#        25.566111, 25.566111, 25.582132, 25.608835, 25.582132, 25.608835,
#        25.595484, 25.595484, 25.595484, 25.582132, 25.595484, 25.595484,
#        25.582132, 25.608835, 25.624857, 25.608835, 25.624857, 25.595484,
#        25.595484, 25.608835, 25.595484, 25.608835, 25.608835, 25.624857,
#        25.608835, 25.608835, 25.624857, 25.638208, 25.608835, 25.624857,
#        25.638208, 25.638208, 25.638208, 25.638208, 25.638208, 25.624857,
#        25.624857, 25.624857, 25.608835, 25.638208, 25.638208, 25.638208,
#        25.65156 , 25.65156 , 25.664911, 25.680933, 25.65156 , 25.664911,
# ...

# %%
temp.min()
# Out:
# 25.523384

# %%
temp.max()
# Out:
# 25.918592

# %%
import plotly.plotly as py

# %%
import plotly.graph_objs as go

# %% [raw]
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(temp)
plt.ylabel('Temperature in Celsius')
plt.xlabel('Time in seconds')
plt.show()

# %%
import requests as rq
import time
import json

# %%
ser
# Out:
# Serial<id=0x7480d70, open=False>(port='COM5', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)

# %%
ser.close()

# %%
temperatures = []
humidity_Lvl = []
light_levels = []
co2_emission = []
totvolorgcom = []
plt.plot(temperatures)
while True:
    data = []
    ser.open()
    import time
    t_end = time.time() + 10
    while time.time() < t_end:
        data = str(ser.readline())[2:-3].split()
        temperatures.append(float(data[0]))
        humidity_Lvl.append(float(data[1]))
        light_levels.append(float(data[2]))
        co2_emission.append(float(data[3]))
        totvolorgcom.append(float(data[4]))
    ser.close()
    #rq.post('http://940185d4.ngrok.io/api/sensors', {'Temperatures' : max(temperatures)})
    plt.hide()
    plt.plot(temperatures)
    plt.ylabel('Temperature in Celsius')
    plt.xlabel('Time in ???')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-9e5354a07c2b> in <module>()
#      18     ser.close()
#      19     #rq.post('http://940185d4.ngrok.io/api/sensors', {'Temperatures' : max(temperatures)})
# ---> 20     plt.hide()
#      21     plt.plot(temperatures)
#      22     plt.ylabel('Temperature in Celsius')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'hide'
